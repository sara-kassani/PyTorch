# %%
import os
import torchvision
from torchvision import transforms
import torch
import torch.nn as nn
import torch.optim as optim
import time
import os.path
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import copy

# %%
print("Torch Version",torch.__version__)
# Out:
# Torch Version 0.4.1

# %%
main_dir = "data/augmented"
data_dir = os.path.join(main_dir, "Wheat")
train_dir = os.path.join(data_dir, "train")
valid_dir = os.path.join(data_dir, "valid")
test_dir = os.path.join(data_dir, "test")

# %%
for root,dirs,files in os.walk(train_dir):
    print (root, len(files))

print("*"*30)
for root,dirs,files in os.walk(valid_dir):
    print (root, len(files))
    
print("*"*30)
for root,dirs,files in os.walk(test_dir):
    print (root, len(files))
# Out:
# data/augmented\Wheat\train 0
# data/augmented\Wheat\train\loged 3360
# data/augmented\Wheat\train\Nonloged 6240
# ******************************
# data/augmented\Wheat\valid 0
# data/augmented\Wheat\valid\loged 848
# data/augmented\Wheat\valid\Nonloged 1552
# ******************************
# data/augmented\Wheat\test 0
# data/augmented\Wheat\test\loged 64
# data/augmented\Wheat\test\Nonloged 122

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

# %%
dataset_mean = [0.485, 0.456, 0.406]
dataset_std = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([transforms.RandomResizedCrop(224),
#                                       transforms.RandomHorizontalFlip(),
#                                       transforms.RandomRotation(10, expand=True),
#                                       transforms.CenterCrop(224),
                                      transforms.Grayscale(num_output_channels=3),
                                      transforms.ToTensor(),
                                      transforms.Normalize(mean=dataset_mean,
                                                            std=dataset_std)])

test_transform = transforms.Compose([transforms.RandomResizedCrop(224),
                                     transforms.Grayscale(num_output_channels=3),
                                     transforms.ToTensor(),
                                     transforms.Normalize(mean=dataset_mean,
                                                            std=dataset_std)])

train_dataset =  torchvision.datasets.ImageFolder(train_dir,
                                                transform=train_transform)

valid_dataset =  torchvision.datasets.ImageFolder(train_dir,
                                                transform=train_transform)

test_dataset =  torchvision.datasets.ImageFolder(test_dir,
                                                transform=test_transform)

batch_size = 16
dataloaders = {}

dataloaders["train"] = torch.utils.data.DataLoader(train_dataset,
                                                   shuffle=True,
                                                   batch_size=batch_size,
                                                   num_workers=1)

dataloaders["valid"] = torch.utils.data.DataLoader(valid_dataset,
                                                   shuffle=True,
                                                   batch_size=batch_size,
                                                   num_workers=1)

dataloaders["test"] = torch.utils.data.DataLoader(test_dataset,
                                                  shuffle=True,
                                                  batch_size=batch_size,
                                                  num_workers=1)

dataset_sizes = {"train": len(train_dataset), 
                 "valid":len(valid_dataset),
                 "test":len(test_dataset)}

# %%
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[str(x.item()) for x in classes])

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
print(dataset_sizes)
print(device)
# Out:
# {'valid': 9600, 'train': 9600, 'test': 186}
# cuda:0

# %%
model = torchvision.models.densenet201(pretrained=True)

#replace the classifier of the trained network with our classifier
num_features = model.classifier.in_features
model.classifier = nn.Sequential(
    nn.Dropout(p=0.15),
    nn.LeakyReLU(0.1),
    nn.Linear(num_features, 2))

criterion = nn.CrossEntropyLoss()
#replace the classifier of the trained network with our classifier
#parameters of newly constructed modules have required_grad=True by default
#model.fc = nn.Linear(num_features, num_classes) 

for param in model.classifier.parameters():
    param.requires_grad = True

model = model.to(device)
criterion = nn.CrossEntropyLoss()
#Optimize only the classifier
optimizer = torch.optim.SGD(list(filter(lambda p: p.requires_grad, model.parameters())), lr=0.001, momentum=0.9)
# Out:
# c:\users\reza-lab\appdata\local\programs\python\python35\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 20)
#         print(".", end="", sep="")
        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
#                 scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
#                 print(".", end="")
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
if torch.cuda.is_available():
    print("Cuda is available.")
    model = torch.nn.DataParallel(model).cuda();

model = train_model(model, criterion, optimizer, scheduler=None, num_epochs=50)
# Out:
# Cuda is available.
# Epoch 0/49
# --------------------
# train Loss: 0.3751 Acc: 0.8418
# valid Loss: 0.2999 Acc: 0.8706
#
# Epoch 1/49
# --------------------
# train Loss: 0.3130 Acc: 0.8738
# valid Loss: 0.2537 Acc: 0.8943
#
# Epoch 2/49
# --------------------
# train Loss: 0.2838 Acc: 0.8856
# valid Loss: 0.2331 Acc: 0.9084
#
# Epoch 3/49
# --------------------
# train Loss: 0.2585 Acc: 0.8933
# valid Loss: 0.2032 Acc: 0.9190
#
# Epoch 4/49
# --------------------
# train Loss: 0.2303 Acc: 0.9065
# valid Loss: 0.1865 Acc: 0.9250
#
# Epoch 5/49
# --------------------
# train Loss: 0.2056 Acc: 0.9166
# valid Loss: 0.1614 Acc: 0.9361
#
# Epoch 6/49
# --------------------
# train Loss: 0.1934 Acc: 0.9202
# valid Loss: 0.1523 Acc: 0.9401
#
# Epoch 7/49
# --------------------
# train Loss: 0.1776 Acc: 0.9265
# valid Loss: 0.1339 Acc: 0.9449
#
# Epoch 8/49
# --------------------
# train Loss: 0.1518 Acc: 0.9399
# valid Loss: 0.1115 Acc: 0.9549
#
# Epoch 9/49
# --------------------
# train Loss: 0.1408 Acc: 0.9436
# valid Loss: 0.1146 Acc: 0.9560
#
# Epoch 10/49
# --------------------
# train Loss: 0.1308 Acc: 0.9466
# valid Loss: 0.0992 Acc: 0.9603
#
# Epoch 11/49
# --------------------
# train Loss: 0.1279 Acc: 0.9493
# valid Loss: 0.1043 Acc: 0.9570
#
# Epoch 12/49
# --------------------
# train Loss: 0.1227 Acc: 0.9506
# valid Loss: 0.0992 Acc: 0.9584
#
# Epoch 13/49
# --------------------
# train Loss: 0.1177 Acc: 0.9529
# valid Loss: 0.0870 Acc: 0.9630
#
# Epoch 14/49
# --------------------
# train Loss: 0.1130 Acc: 0.9556
# valid Loss: 0.0791 Acc: 0.9691
#
# Epoch 15/49
# --------------------
# train Loss: 0.1099 Acc: 0.9578
# valid Loss: 0.0914 Acc: 0.9636
#
# Epoch 16/49
# --------------------
# train Loss: 0.0999 Acc: 0.9614
# valid Loss: 0.0896 Acc: 0.9627
#
# Epoch 17/49
# --------------------
# train Loss: 0.0924 Acc: 0.9663
# valid Loss: 0.0834 Acc: 0.9657
#
# Epoch 18/49
# --------------------
# train Loss: 0.0899 Acc: 0.9642
# valid Loss: 0.0737 Acc: 0.9714
#
# Epoch 19/49
# --------------------
# train Loss: 0.0879 Acc: 0.9640
# valid Loss: 0.0773 Acc: 0.9682
#
# Epoch 20/49
# --------------------
# train Loss: 0.0910 Acc: 0.9651
# valid Loss: 0.0782 Acc: 0.9693
#
# Epoch 21/49
# --------------------
# train Loss: 0.0803 Acc: 0.9666
# valid Loss: 0.0734 Acc: 0.9724
#
# Epoch 22/49
# --------------------
# train Loss: 0.0760 Acc: 0.9692
# valid Loss: 0.0713 Acc: 0.9685
#
# Epoch 23/49
# --------------------
# train Loss: 0.0724 Acc: 0.9704
# valid Loss: 0.0544 Acc: 0.9791
#
# Epoch 24/49
# --------------------
# train Loss: 0.0759 Acc: 0.9708
# valid Loss: 0.0664 Acc: 0.9724
#
# Epoch 25/49
# --------------------
# train Loss: 0.0743 Acc: 0.9721
# valid Loss: 0.0711 Acc: 0.9717
#
# Epoch 26/49
# --------------------
# train Loss: 0.0658 Acc: 0.9747
# valid Loss: 0.0639 Acc: 0.9746
#
# Epoch 27/49
# --------------------
# train Loss: 0.0698 Acc: 0.9715
# valid Loss: 0.0653 Acc: 0.9736
#
# Epoch 28/49
# --------------------
# train Loss: 0.1070 Acc: 0.9604
# valid Loss: 0.0712 Acc: 0.9720
#
# Epoch 29/49
# --------------------
# train Loss: 0.0739 Acc: 0.9704
# valid Loss: 0.0558 Acc: 0.9769
#
# Epoch 30/49
# --------------------
# train Loss: 0.0694 Acc: 0.9731
# valid Loss: 0.0491 Acc: 0.9807
#
# Epoch 31/49
# --------------------
# train Loss: 0.0683 Acc: 0.9725
# valid Loss: 0.0619 Acc: 0.9760
#
# Epoch 32/49
# --------------------
# train Loss: 0.0732 Acc: 0.9709
# valid Loss: 0.0503 Acc: 0.9830
#
# Epoch 33/49
# --------------------
# train Loss: 0.0614 Acc: 0.9750
# valid Loss: 0.0508 Acc: 0.9803
#
# Epoch 34/49
# --------------------
# train Loss: 0.0605 Acc: 0.9757
# valid Loss: 0.0620 Acc: 0.9754
#
# Epoch 35/49
# --------------------
# train Loss: 0.0575 Acc: 0.9771
# valid Loss: 0.0421 Acc: 0.9835
#
# Epoch 36/49
# --------------------
# train Loss: 0.0573 Acc: 0.9769
# valid Loss: 0.0461 Acc: 0.9815
#
# Epoch 37/49
# --------------------
# train Loss: 0.0531 Acc: 0.9794
# valid Loss: 0.0423 Acc: 0.9835
#
# Epoch 38/49
# --------------------
# train Loss: 0.0571 Acc: 0.9764
# valid Loss: 0.0391 Acc: 0.9835
#
# Epoch 39/49
# --------------------
# train Loss: 0.0499 Acc: 0.9804
# valid Loss: 0.0437 Acc: 0.9823
#
# Epoch 40/49
# --------------------
# train Loss: 0.0595 Acc: 0.9766
# valid Loss: 0.0389 Acc: 0.9849
#
# Epoch 41/49
# --------------------
# train Loss: 0.0570 Acc: 0.9778
# valid Loss: 0.0435 Acc: 0.9818
#
# Epoch 42/49
# --------------------
# train Loss: 0.0465 Acc: 0.9831
# valid Loss: 0.0423 Acc: 0.9826
#
# Epoch 43/49
# --------------------
# train Loss: 0.0534 Acc: 0.9809
# valid Loss: 0.0452 Acc: 0.9829
#
# Epoch 44/49
# --------------------
# train Loss: 0.0531 Acc: 0.9784
# valid Loss: 0.0531 Acc: 0.9784
#
# Epoch 45/49
# --------------------
# train Loss: 0.0523 Acc: 0.9801
# valid Loss: 0.0368 Acc: 0.9865
#
# Epoch 46/49
# --------------------
# train Loss: 0.0509 Acc: 0.9779
# valid Loss: 0.0348 Acc: 0.9867
#
# Epoch 47/49
# --------------------
# train Loss: 0.0558 Acc: 0.9779
# valid Loss: 0.0408 Acc: 0.9848
#
# Epoch 48/49
# --------------------
# train Loss: 0.0533 Acc: 0.9777
# valid Loss: 0.0379 Acc: 0.9855
#
# Epoch 49/49
# --------------------
# train Loss: 0.0469 Acc: 0.9822
# valid Loss: 0.0384 Acc: 0.9851
#
# Training complete in 260m 10s
# Best val Acc: 0.986667

# %%
torch.save(model.state_dict(), "models/09.Wheat-DenseNet201-Fine-Tuned_augmented.pth")

# %%
correct = 0
total = 0
loss = 0
y_pred = []
y_true = []

with torch.no_grad():
    for data in dataloaders["test"]:
        images, labels = data
        images = images.cuda()
        labels = labels.cuda()
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        test_loss = criterion(outputs, labels)
        
        y_pred += predicted.to("cpu").detach().numpy().tolist()
        y_true += labels.to("cpu").detach().numpy().tolist()
        
print('Test accuracy: {:.4f}' .format( 100 * correct / total))
print('Test Loss: %.4f'%(test_loss))
# Out:
# Test accuracy: 86.5591
# Test Loss: 0.2234

# %%
plt.rcParams["axes.grid"] = False
plt.rcParams.update({'font.size': 20})

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred)

   
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion Matrix')

    print(cm)
#     fig = plt.figure()
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
#     plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
#     plt.savefig('plots/3.InceptionV3-2-Private-DataSet-CM.png', bbox_inches='tight', dpi = 100) 
plt.figure(figsize=(10,10))

labels = ['0', '1']

plot_confusion_matrix(cm, classes=labels,
                      title='Confusion Matrix')
# Out:
# Confusion Matrix
# [[110  12]
#  [ 13  51]]

# %%
cm = confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# [[110  12]
#  [ 13  51]]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
classnames=[]
for classname in dataloaders["test"]:
    classnames.append(classname)

confusion_mtx = confusion_matrix(y_true, y_pred) 
print(confusion_mtx)
target_names = classnames
# print(classification_report(y_true, y_pred, target_names=target_names))
print(classification_report(y_true, y_pred))
# Out:
# [[110  12]
#  [ 13  51]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90       122
#            1       0.81      0.80      0.80        64
#
#    micro avg       0.87      0.87      0.87       186
#    macro avg       0.85      0.85      0.85       186
# weighted avg       0.87      0.87      0.87       186

# %%
total=sum(sum(cm))

accuracy = (cm[0,0]+cm[1,1]) / total
print ('Accuracy : ', accuracy*100)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity*100 )

Specificity = cm[1,1]/(cm[1,1]+cm[0,1])
print('Specificity : ', Specificity*100 )
# Out:
# Accuracy :  86.55913978494624
# Sensitivity :  89.43089430894308
# Specificity :  80.95238095238095

# %%
plt.rcParams["axes.grid"] = False
plt.rcParams.update({'font.size': 14})

from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_true, y_pred)
roc_auc = auc(fpr, tpr)

import matplotlib.pyplot as plt

plt.figure()
lw = 1
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

#plotting sensitivity and specificity
plt.figure()
plt.plot(thresholds, 1-fpr, label = 'specificity')
plt.plot(thresholds, tpr, label = 'sensitivity')
plt.legend()
plt.grid()
plt.xlabel('Threshold value')
plt.show()

# %%
# To view which layers are freeze and which layers are not freezed:
for name, child in model.named_children():
    for name_2, params in child.named_parameters():
        print(name_2, params.requires_grad)
# Out:
# module.features.conv0.weight True
# module.features.norm0.weight True
# module.features.norm0.bias True
# module.features.denseblock1.denselayer1.norm1.weight True
# module.features.denseblock1.denselayer1.norm1.bias True
# module.features.denseblock1.denselayer1.conv1.weight True
# module.features.denseblock1.denselayer1.norm2.weight True
# module.features.denseblock1.denselayer1.norm2.bias True
# module.features.denseblock1.denselayer1.conv2.weight True
# module.features.denseblock1.denselayer2.norm1.weight True
# module.features.denseblock1.denselayer2.norm1.bias True
# module.features.denseblock1.denselayer2.conv1.weight True
# module.features.denseblock1.denselayer2.norm2.weight True
# module.features.denseblock1.denselayer2.norm2.bias True
# module.features.denseblock1.denselayer2.conv2.weight True
# module.features.denseblock1.denselayer3.norm1.weight True
# module.features.denseblock1.denselayer3.norm1.bias True
# module.features.denseblock1.denselayer3.conv1.weight True
# module.features.denseblock1.denselayer3.norm2.weight True
# module.features.denseblock1.denselayer3.norm2.bias True
# module.features.denseblock1.denselayer3.conv2.weight True
# module.features.denseblock1.denselayer4.norm1.weight True
# module.features.denseblock1.denselayer4.norm1.bias True
# module.features.denseblock1.denselayer4.conv1.weight True
# module.features.denseblock1.denselayer4.norm2.weight True
# module.features.denseblock1.denselayer4.norm2.bias True
# module.features.denseblock1.denselayer4.conv2.weight True
# module.features.denseblock1.denselayer5.norm1.weight True
# module.features.denseblock1.denselayer5.norm1.bias True
# module.features.denseblock1.denselayer5.conv1.weight True
# module.features.denseblock1.denselayer5.norm2.weight True
# module.features.denseblock1.denselayer5.norm2.bias True
# module.features.denseblock1.denselayer5.conv2.weight True
# module.features.denseblock1.denselayer6.norm1.weight True
# module.features.denseblock1.denselayer6.norm1.bias True
# module.features.denseblock1.denselayer6.conv1.weight True
# module.features.denseblock1.denselayer6.norm2.weight True
# module.features.denseblock1.denselayer6.norm2.bias True
# module.features.denseblock1.denselayer6.conv2.weight True
# module.features.transition1.norm.weight True
# module.features.transition1.norm.bias True
# module.features.transition1.conv.weight True
# module.features.denseblock2.denselayer1.norm1.weight True
# module.features.denseblock2.denselayer1.norm1.bias True
# module.features.denseblock2.denselayer1.conv1.weight True
# module.features.denseblock2.denselayer1.norm2.weight True
# module.features.denseblock2.denselayer1.norm2.bias True
# module.features.denseblock2.denselayer1.conv2.weight True
# module.features.denseblock2.denselayer2.norm1.weight True
# module.features.denseblock2.denselayer2.norm1.bias True
# module.features.denseblock2.denselayer2.conv1.weight True
# module.features.denseblock2.denselayer2.norm2.weight True
# module.features.denseblock2.denselayer2.norm2.bias True
# module.features.denseblock2.denselayer2.conv2.weight True
# module.features.denseblock2.denselayer3.norm1.weight True
# module.features.denseblock2.denselayer3.norm1.bias True
# module.features.denseblock2.denselayer3.conv1.weight True
# module.features.denseblock2.denselayer3.norm2.weight True
# module.features.denseblock2.denselayer3.norm2.bias True
# module.features.denseblock2.denselayer3.conv2.weight True
# module.features.denseblock2.denselayer4.norm1.weight True
# module.features.denseblock2.denselayer4.norm1.bias True
# module.features.denseblock2.denselayer4.conv1.weight True
# module.features.denseblock2.denselayer4.norm2.weight True
# module.features.denseblock2.denselayer4.norm2.bias True
# module.features.denseblock2.denselayer4.conv2.weight True
# module.features.denseblock2.denselayer5.norm1.weight True
# module.features.denseblock2.denselayer5.norm1.bias True
# module.features.denseblock2.denselayer5.conv1.weight True
# module.features.denseblock2.denselayer5.norm2.weight True
# module.features.denseblock2.denselayer5.norm2.bias True
# module.features.denseblock2.denselayer5.conv2.weight True
# module.features.denseblock2.denselayer6.norm1.weight True
# module.features.denseblock2.denselayer6.norm1.bias True
# module.features.denseblock2.denselayer6.conv1.weight True
# module.features.denseblock2.denselayer6.norm2.weight True
# module.features.denseblock2.denselayer6.norm2.bias True
# module.features.denseblock2.denselayer6.conv2.weight True
# module.features.denseblock2.denselayer7.norm1.weight True
# module.features.denseblock2.denselayer7.norm1.bias True
# module.features.denseblock2.denselayer7.conv1.weight True
# module.features.denseblock2.denselayer7.norm2.weight True
# module.features.denseblock2.denselayer7.norm2.bias True
# module.features.denseblock2.denselayer7.conv2.weight True
# module.features.denseblock2.denselayer8.norm1.weight True
# module.features.denseblock2.denselayer8.norm1.bias True
# module.features.denseblock2.denselayer8.conv1.weight True
# module.features.denseblock2.denselayer8.norm2.weight True
# module.features.denseblock2.denselayer8.norm2.bias True
# module.features.denseblock2.denselayer8.conv2.weight True
# module.features.denseblock2.denselayer9.norm1.weight True
# module.features.denseblock2.denselayer9.norm1.bias True
# module.features.denseblock2.denselayer9.conv1.weight True
# module.features.denseblock2.denselayer9.norm2.weight True
# module.features.denseblock2.denselayer9.norm2.bias True
# module.features.denseblock2.denselayer9.conv2.weight True
# module.features.denseblock2.denselayer10.norm1.weight True
# module.features.denseblock2.denselayer10.norm1.bias True
# module.features.denseblock2.denselayer10.conv1.weight True
# module.features.denseblock2.denselayer10.norm2.weight True
# module.features.denseblock2.denselayer10.norm2.bias True
# module.features.denseblock2.denselayer10.conv2.weight True
# module.features.denseblock2.denselayer11.norm1.weight True
# module.features.denseblock2.denselayer11.norm1.bias True
# module.features.denseblock2.denselayer11.conv1.weight True
# module.features.denseblock2.denselayer11.norm2.weight True
# module.features.denseblock2.denselayer11.norm2.bias True
# module.features.denseblock2.denselayer11.conv2.weight True
# module.features.denseblock2.denselayer12.norm1.weight True
# module.features.denseblock2.denselayer12.norm1.bias True
# module.features.denseblock2.denselayer12.conv1.weight True
# module.features.denseblock2.denselayer12.norm2.weight True
# module.features.denseblock2.denselayer12.norm2.bias True
# module.features.denseblock2.denselayer12.conv2.weight True
# module.features.transition2.norm.weight True
# module.features.transition2.norm.bias True
# module.features.transition2.conv.weight True
# module.features.denseblock3.denselayer1.norm1.weight True
# module.features.denseblock3.denselayer1.norm1.bias True
# module.features.denseblock3.denselayer1.conv1.weight True
# module.features.denseblock3.denselayer1.norm2.weight True
# module.features.denseblock3.denselayer1.norm2.bias True
# module.features.denseblock3.denselayer1.conv2.weight True
# module.features.denseblock3.denselayer2.norm1.weight True
# module.features.denseblock3.denselayer2.norm1.bias True
# module.features.denseblock3.denselayer2.conv1.weight True
# module.features.denseblock3.denselayer2.norm2.weight True
# module.features.denseblock3.denselayer2.norm2.bias True
# module.features.denseblock3.denselayer2.conv2.weight True
# module.features.denseblock3.denselayer3.norm1.weight True
# module.features.denseblock3.denselayer3.norm1.bias True
# module.features.denseblock3.denselayer3.conv1.weight True
# module.features.denseblock3.denselayer3.norm2.weight True
# module.features.denseblock3.denselayer3.norm2.bias True
# module.features.denseblock3.denselayer3.conv2.weight True
# module.features.denseblock3.denselayer4.norm1.weight True
# module.features.denseblock3.denselayer4.norm1.bias True
# module.features.denseblock3.denselayer4.conv1.weight True
# module.features.denseblock3.denselayer4.norm2.weight True
# module.features.denseblock3.denselayer4.norm2.bias True
# module.features.denseblock3.denselayer4.conv2.weight True
# module.features.denseblock3.denselayer5.norm1.weight True
# module.features.denseblock3.denselayer5.norm1.bias True
# module.features.denseblock3.denselayer5.conv1.weight True
# module.features.denseblock3.denselayer5.norm2.weight True
# module.features.denseblock3.denselayer5.norm2.bias True
# module.features.denseblock3.denselayer5.conv2.weight True
# module.features.denseblock3.denselayer6.norm1.weight True
# module.features.denseblock3.denselayer6.norm1.bias True
# module.features.denseblock3.denselayer6.conv1.weight True
# module.features.denseblock3.denselayer6.norm2.weight True
# module.features.denseblock3.denselayer6.norm2.bias True
# module.features.denseblock3.denselayer6.conv2.weight True
# module.features.denseblock3.denselayer7.norm1.weight True
# module.features.denseblock3.denselayer7.norm1.bias True
# module.features.denseblock3.denselayer7.conv1.weight True
# module.features.denseblock3.denselayer7.norm2.weight True
# module.features.denseblock3.denselayer7.norm2.bias True
# module.features.denseblock3.denselayer7.conv2.weight True
# module.features.denseblock3.denselayer8.norm1.weight True
# module.features.denseblock3.denselayer8.norm1.bias True
# module.features.denseblock3.denselayer8.conv1.weight True
# module.features.denseblock3.denselayer8.norm2.weight True
# module.features.denseblock3.denselayer8.norm2.bias True
# module.features.denseblock3.denselayer8.conv2.weight True
# module.features.denseblock3.denselayer9.norm1.weight True
# module.features.denseblock3.denselayer9.norm1.bias True
# module.features.denseblock3.denselayer9.conv1.weight True
# module.features.denseblock3.denselayer9.norm2.weight True
# module.features.denseblock3.denselayer9.norm2.bias True
# module.features.denseblock3.denselayer9.conv2.weight True
# module.features.denseblock3.denselayer10.norm1.weight True
# module.features.denseblock3.denselayer10.norm1.bias True
# module.features.denseblock3.denselayer10.conv1.weight True
# module.features.denseblock3.denselayer10.norm2.weight True
# module.features.denseblock3.denselayer10.norm2.bias True
# module.features.denseblock3.denselayer10.conv2.weight True
# module.features.denseblock3.denselayer11.norm1.weight True
# module.features.denseblock3.denselayer11.norm1.bias True
# module.features.denseblock3.denselayer11.conv1.weight True
# module.features.denseblock3.denselayer11.norm2.weight True
# module.features.denseblock3.denselayer11.norm2.bias True
# module.features.denseblock3.denselayer11.conv2.weight True
# module.features.denseblock3.denselayer12.norm1.weight True
# module.features.denseblock3.denselayer12.norm1.bias True
# module.features.denseblock3.denselayer12.conv1.weight True
# module.features.denseblock3.denselayer12.norm2.weight True
# module.features.denseblock3.denselayer12.norm2.bias True
# module.features.denseblock3.denselayer12.conv2.weight True
# module.features.denseblock3.denselayer13.norm1.weight True
# module.features.denseblock3.denselayer13.norm1.bias True
# module.features.denseblock3.denselayer13.conv1.weight True
# module.features.denseblock3.denselayer13.norm2.weight True
# module.features.denseblock3.denselayer13.norm2.bias True
# module.features.denseblock3.denselayer13.conv2.weight True
# module.features.denseblock3.denselayer14.norm1.weight True
# module.features.denseblock3.denselayer14.norm1.bias True
# module.features.denseblock3.denselayer14.conv1.weight True
# module.features.denseblock3.denselayer14.norm2.weight True
# module.features.denseblock3.denselayer14.norm2.bias True
# module.features.denseblock3.denselayer14.conv2.weight True
# module.features.denseblock3.denselayer15.norm1.weight True
# module.features.denseblock3.denselayer15.norm1.bias True
# module.features.denseblock3.denselayer15.conv1.weight True
# module.features.denseblock3.denselayer15.norm2.weight True
# module.features.denseblock3.denselayer15.norm2.bias True
# module.features.denseblock3.denselayer15.conv2.weight True
# module.features.denseblock3.denselayer16.norm1.weight True
# module.features.denseblock3.denselayer16.norm1.bias True
# module.features.denseblock3.denselayer16.conv1.weight True
# module.features.denseblock3.denselayer16.norm2.weight True
# module.features.denseblock3.denselayer16.norm2.bias True
# module.features.denseblock3.denselayer16.conv2.weight True
# module.features.denseblock3.denselayer17.norm1.weight True
# module.features.denseblock3.denselayer17.norm1.bias True
# module.features.denseblock3.denselayer17.conv1.weight True
# module.features.denseblock3.denselayer17.norm2.weight True
# module.features.denseblock3.denselayer17.norm2.bias True
# module.features.denseblock3.denselayer17.conv2.weight True
# module.features.denseblock3.denselayer18.norm1.weight True
# module.features.denseblock3.denselayer18.norm1.bias True
# module.features.denseblock3.denselayer18.conv1.weight True
# module.features.denseblock3.denselayer18.norm2.weight True
# module.features.denseblock3.denselayer18.norm2.bias True
# module.features.denseblock3.denselayer18.conv2.weight True
# module.features.denseblock3.denselayer19.norm1.weight True
# module.features.denseblock3.denselayer19.norm1.bias True
# module.features.denseblock3.denselayer19.conv1.weight True
# module.features.denseblock3.denselayer19.norm2.weight True
# module.features.denseblock3.denselayer19.norm2.bias True
# module.features.denseblock3.denselayer19.conv2.weight True
# module.features.denseblock3.denselayer20.norm1.weight True
# module.features.denseblock3.denselayer20.norm1.bias True
# module.features.denseblock3.denselayer20.conv1.weight True
# module.features.denseblock3.denselayer20.norm2.weight True
# module.features.denseblock3.denselayer20.norm2.bias True
# module.features.denseblock3.denselayer20.conv2.weight True
# module.features.denseblock3.denselayer21.norm1.weight True
# module.features.denseblock3.denselayer21.norm1.bias True
# module.features.denseblock3.denselayer21.conv1.weight True
# module.features.denseblock3.denselayer21.norm2.weight True
# module.features.denseblock3.denselayer21.norm2.bias True
# module.features.denseblock3.denselayer21.conv2.weight True
# module.features.denseblock3.denselayer22.norm1.weight True
# module.features.denseblock3.denselayer22.norm1.bias True
# module.features.denseblock3.denselayer22.conv1.weight True
# module.features.denseblock3.denselayer22.norm2.weight True
# module.features.denseblock3.denselayer22.norm2.bias True
# module.features.denseblock3.denselayer22.conv2.weight True
# module.features.denseblock3.denselayer23.norm1.weight True
# module.features.denseblock3.denselayer23.norm1.bias True
# module.features.denseblock3.denselayer23.conv1.weight True
# module.features.denseblock3.denselayer23.norm2.weight True
# module.features.denseblock3.denselayer23.norm2.bias True
# module.features.denseblock3.denselayer23.conv2.weight True
# module.features.denseblock3.denselayer24.norm1.weight True
# module.features.denseblock3.denselayer24.norm1.bias True
# module.features.denseblock3.denselayer24.conv1.weight True
# module.features.denseblock3.denselayer24.norm2.weight True
# module.features.denseblock3.denselayer24.norm2.bias True
# module.features.denseblock3.denselayer24.conv2.weight True
# module.features.denseblock3.denselayer25.norm1.weight True
# module.features.denseblock3.denselayer25.norm1.bias True
# module.features.denseblock3.denselayer25.conv1.weight True
# module.features.denseblock3.denselayer25.norm2.weight True
# module.features.denseblock3.denselayer25.norm2.bias True
# module.features.denseblock3.denselayer25.conv2.weight True
# module.features.denseblock3.denselayer26.norm1.weight True
# module.features.denseblock3.denselayer26.norm1.bias True
# module.features.denseblock3.denselayer26.conv1.weight True
# module.features.denseblock3.denselayer26.norm2.weight True
# module.features.denseblock3.denselayer26.norm2.bias True
# module.features.denseblock3.denselayer26.conv2.weight True
# module.features.denseblock3.denselayer27.norm1.weight True
# module.features.denseblock3.denselayer27.norm1.bias True
# module.features.denseblock3.denselayer27.conv1.weight True
# module.features.denseblock3.denselayer27.norm2.weight True
# module.features.denseblock3.denselayer27.norm2.bias True
# module.features.denseblock3.denselayer27.conv2.weight True
# module.features.denseblock3.denselayer28.norm1.weight True
# module.features.denseblock3.denselayer28.norm1.bias True
# module.features.denseblock3.denselayer28.conv1.weight True
# module.features.denseblock3.denselayer28.norm2.weight True
# module.features.denseblock3.denselayer28.norm2.bias True
# module.features.denseblock3.denselayer28.conv2.weight True
# module.features.denseblock3.denselayer29.norm1.weight True
# module.features.denseblock3.denselayer29.norm1.bias True
# module.features.denseblock3.denselayer29.conv1.weight True
# module.features.denseblock3.denselayer29.norm2.weight True
# module.features.denseblock3.denselayer29.norm2.bias True
# module.features.denseblock3.denselayer29.conv2.weight True
# module.features.denseblock3.denselayer30.norm1.weight True
# module.features.denseblock3.denselayer30.norm1.bias True
# module.features.denseblock3.denselayer30.conv1.weight True
# module.features.denseblock3.denselayer30.norm2.weight True
# module.features.denseblock3.denselayer30.norm2.bias True
# module.features.denseblock3.denselayer30.conv2.weight True
# module.features.denseblock3.denselayer31.norm1.weight True
# module.features.denseblock3.denselayer31.norm1.bias True
# module.features.denseblock3.denselayer31.conv1.weight True
# module.features.denseblock3.denselayer31.norm2.weight True
# module.features.denseblock3.denselayer31.norm2.bias True
# module.features.denseblock3.denselayer31.conv2.weight True
# module.features.denseblock3.denselayer32.norm1.weight True
# module.features.denseblock3.denselayer32.norm1.bias True
# module.features.denseblock3.denselayer32.conv1.weight True
# module.features.denseblock3.denselayer32.norm2.weight True
# module.features.denseblock3.denselayer32.norm2.bias True
# module.features.denseblock3.denselayer32.conv2.weight True
# module.features.denseblock3.denselayer33.norm1.weight True
# module.features.denseblock3.denselayer33.norm1.bias True
# module.features.denseblock3.denselayer33.conv1.weight True
# module.features.denseblock3.denselayer33.norm2.weight True
# module.features.denseblock3.denselayer33.norm2.bias True
# module.features.denseblock3.denselayer33.conv2.weight True
# module.features.denseblock3.denselayer34.norm1.weight True
# module.features.denseblock3.denselayer34.norm1.bias True
# module.features.denseblock3.denselayer34.conv1.weight True
# module.features.denseblock3.denselayer34.norm2.weight True
# module.features.denseblock3.denselayer34.norm2.bias True
# module.features.denseblock3.denselayer34.conv2.weight True
# module.features.denseblock3.denselayer35.norm1.weight True
# module.features.denseblock3.denselayer35.norm1.bias True
# module.features.denseblock3.denselayer35.conv1.weight True
# module.features.denseblock3.denselayer35.norm2.weight True
# module.features.denseblock3.denselayer35.norm2.bias True
# module.features.denseblock3.denselayer35.conv2.weight True
# module.features.denseblock3.denselayer36.norm1.weight True
# module.features.denseblock3.denselayer36.norm1.bias True
# module.features.denseblock3.denselayer36.conv1.weight True
# module.features.denseblock3.denselayer36.norm2.weight True
# module.features.denseblock3.denselayer36.norm2.bias True
# module.features.denseblock3.denselayer36.conv2.weight True
# module.features.denseblock3.denselayer37.norm1.weight True
# module.features.denseblock3.denselayer37.norm1.bias True
# module.features.denseblock3.denselayer37.conv1.weight True
# module.features.denseblock3.denselayer37.norm2.weight True
# module.features.denseblock3.denselayer37.norm2.bias True
# module.features.denseblock3.denselayer37.conv2.weight True
# module.features.denseblock3.denselayer38.norm1.weight True
# module.features.denseblock3.denselayer38.norm1.bias True
# module.features.denseblock3.denselayer38.conv1.weight True
# module.features.denseblock3.denselayer38.norm2.weight True
# module.features.denseblock3.denselayer38.norm2.bias True
# module.features.denseblock3.denselayer38.conv2.weight True
# module.features.denseblock3.denselayer39.norm1.weight True
# module.features.denseblock3.denselayer39.norm1.bias True
# module.features.denseblock3.denselayer39.conv1.weight True
# module.features.denseblock3.denselayer39.norm2.weight True
# module.features.denseblock3.denselayer39.norm2.bias True
# module.features.denseblock3.denselayer39.conv2.weight True
# module.features.denseblock3.denselayer40.norm1.weight True
# module.features.denseblock3.denselayer40.norm1.bias True
# module.features.denseblock3.denselayer40.conv1.weight True
# module.features.denseblock3.denselayer40.norm2.weight True
# module.features.denseblock3.denselayer40.norm2.bias True
# module.features.denseblock3.denselayer40.conv2.weight True
# module.features.denseblock3.denselayer41.norm1.weight True
# module.features.denseblock3.denselayer41.norm1.bias True
# module.features.denseblock3.denselayer41.conv1.weight True
# module.features.denseblock3.denselayer41.norm2.weight True
# module.features.denseblock3.denselayer41.norm2.bias True
# module.features.denseblock3.denselayer41.conv2.weight True
# module.features.denseblock3.denselayer42.norm1.weight True
# module.features.denseblock3.denselayer42.norm1.bias True
# module.features.denseblock3.denselayer42.conv1.weight True
# module.features.denseblock3.denselayer42.norm2.weight True
# module.features.denseblock3.denselayer42.norm2.bias True
# module.features.denseblock3.denselayer42.conv2.weight True
# module.features.denseblock3.denselayer43.norm1.weight True
# module.features.denseblock3.denselayer43.norm1.bias True
# module.features.denseblock3.denselayer43.conv1.weight True
# module.features.denseblock3.denselayer43.norm2.weight True
# module.features.denseblock3.denselayer43.norm2.bias True
# module.features.denseblock3.denselayer43.conv2.weight True
# module.features.denseblock3.denselayer44.norm1.weight True
# module.features.denseblock3.denselayer44.norm1.bias True
# module.features.denseblock3.denselayer44.conv1.weight True
# module.features.denseblock3.denselayer44.norm2.weight True
# module.features.denseblock3.denselayer44.norm2.bias True
# module.features.denseblock3.denselayer44.conv2.weight True
# module.features.denseblock3.denselayer45.norm1.weight True
# module.features.denseblock3.denselayer45.norm1.bias True
# module.features.denseblock3.denselayer45.conv1.weight True
# module.features.denseblock3.denselayer45.norm2.weight True
# module.features.denseblock3.denselayer45.norm2.bias True
# module.features.denseblock3.denselayer45.conv2.weight True
# module.features.denseblock3.denselayer46.norm1.weight True
# module.features.denseblock3.denselayer46.norm1.bias True
# module.features.denseblock3.denselayer46.conv1.weight True
# module.features.denseblock3.denselayer46.norm2.weight True
# module.features.denseblock3.denselayer46.norm2.bias True
# module.features.denseblock3.denselayer46.conv2.weight True
# module.features.denseblock3.denselayer47.norm1.weight True
# module.features.denseblock3.denselayer47.norm1.bias True
# module.features.denseblock3.denselayer47.conv1.weight True
# module.features.denseblock3.denselayer47.norm2.weight True
# module.features.denseblock3.denselayer47.norm2.bias True
# module.features.denseblock3.denselayer47.conv2.weight True
# module.features.denseblock3.denselayer48.norm1.weight True
# module.features.denseblock3.denselayer48.norm1.bias True
# module.features.denseblock3.denselayer48.conv1.weight True
# module.features.denseblock3.denselayer48.norm2.weight True
# module.features.denseblock3.denselayer48.norm2.bias True
# module.features.denseblock3.denselayer48.conv2.weight True
# module.features.transition3.norm.weight True
# module.features.transition3.norm.bias True
# module.features.transition3.conv.weight True
# module.features.denseblock4.denselayer1.norm1.weight True
# module.features.denseblock4.denselayer1.norm1.bias True
# module.features.denseblock4.denselayer1.conv1.weight True
# module.features.denseblock4.denselayer1.norm2.weight True
# module.features.denseblock4.denselayer1.norm2.bias True
# module.features.denseblock4.denselayer1.conv2.weight True
# module.features.denseblock4.denselayer2.norm1.weight True
# module.features.denseblock4.denselayer2.norm1.bias True
# module.features.denseblock4.denselayer2.conv1.weight True
# module.features.denseblock4.denselayer2.norm2.weight True
# module.features.denseblock4.denselayer2.norm2.bias True
# module.features.denseblock4.denselayer2.conv2.weight True
# module.features.denseblock4.denselayer3.norm1.weight True
# module.features.denseblock4.denselayer3.norm1.bias True
# module.features.denseblock4.denselayer3.conv1.weight True
# module.features.denseblock4.denselayer3.norm2.weight True
# module.features.denseblock4.denselayer3.norm2.bias True
# module.features.denseblock4.denselayer3.conv2.weight True
# module.features.denseblock4.denselayer4.norm1.weight True
# module.features.denseblock4.denselayer4.norm1.bias True
# module.features.denseblock4.denselayer4.conv1.weight True
# module.features.denseblock4.denselayer4.norm2.weight True
# module.features.denseblock4.denselayer4.norm2.bias True
# module.features.denseblock4.denselayer4.conv2.weight True
# module.features.denseblock4.denselayer5.norm1.weight True
# module.features.denseblock4.denselayer5.norm1.bias True
# module.features.denseblock4.denselayer5.conv1.weight True
# module.features.denseblock4.denselayer5.norm2.weight True
# module.features.denseblock4.denselayer5.norm2.bias True
# module.features.denseblock4.denselayer5.conv2.weight True
# module.features.denseblock4.denselayer6.norm1.weight True
# module.features.denseblock4.denselayer6.norm1.bias True
# module.features.denseblock4.denselayer6.conv1.weight True
# module.features.denseblock4.denselayer6.norm2.weight True
# module.features.denseblock4.denselayer6.norm2.bias True
# module.features.denseblock4.denselayer6.conv2.weight True
# module.features.denseblock4.denselayer7.norm1.weight True
# module.features.denseblock4.denselayer7.norm1.bias True
# module.features.denseblock4.denselayer7.conv1.weight True
# module.features.denseblock4.denselayer7.norm2.weight True
# module.features.denseblock4.denselayer7.norm2.bias True
# module.features.denseblock4.denselayer7.conv2.weight True
# module.features.denseblock4.denselayer8.norm1.weight True
# module.features.denseblock4.denselayer8.norm1.bias True
# module.features.denseblock4.denselayer8.conv1.weight True
# module.features.denseblock4.denselayer8.norm2.weight True
# module.features.denseblock4.denselayer8.norm2.bias True
# module.features.denseblock4.denselayer8.conv2.weight True
# module.features.denseblock4.denselayer9.norm1.weight True
# module.features.denseblock4.denselayer9.norm1.bias True
# module.features.denseblock4.denselayer9.conv1.weight True
# module.features.denseblock4.denselayer9.norm2.weight True
# module.features.denseblock4.denselayer9.norm2.bias True
# module.features.denseblock4.denselayer9.conv2.weight True
# module.features.denseblock4.denselayer10.norm1.weight True
# module.features.denseblock4.denselayer10.norm1.bias True
# module.features.denseblock4.denselayer10.conv1.weight True
# module.features.denseblock4.denselayer10.norm2.weight True
# module.features.denseblock4.denselayer10.norm2.bias True
# module.features.denseblock4.denselayer10.conv2.weight True
# module.features.denseblock4.denselayer11.norm1.weight True
# module.features.denseblock4.denselayer11.norm1.bias True
# module.features.denseblock4.denselayer11.conv1.weight True
# module.features.denseblock4.denselayer11.norm2.weight True
# module.features.denseblock4.denselayer11.norm2.bias True
# module.features.denseblock4.denselayer11.conv2.weight True
# module.features.denseblock4.denselayer12.norm1.weight True
# module.features.denseblock4.denselayer12.norm1.bias True
# module.features.denseblock4.denselayer12.conv1.weight True
# module.features.denseblock4.denselayer12.norm2.weight True
# module.features.denseblock4.denselayer12.norm2.bias True
# module.features.denseblock4.denselayer12.conv2.weight True
# module.features.denseblock4.denselayer13.norm1.weight True
# module.features.denseblock4.denselayer13.norm1.bias True
# module.features.denseblock4.denselayer13.conv1.weight True
# module.features.denseblock4.denselayer13.norm2.weight True
# module.features.denseblock4.denselayer13.norm2.bias True
# module.features.denseblock4.denselayer13.conv2.weight True
# module.features.denseblock4.denselayer14.norm1.weight True
# module.features.denseblock4.denselayer14.norm1.bias True
# module.features.denseblock4.denselayer14.conv1.weight True
# module.features.denseblock4.denselayer14.norm2.weight True
# module.features.denseblock4.denselayer14.norm2.bias True
# module.features.denseblock4.denselayer14.conv2.weight True
# module.features.denseblock4.denselayer15.norm1.weight True
# module.features.denseblock4.denselayer15.norm1.bias True
# module.features.denseblock4.denselayer15.conv1.weight True
# module.features.denseblock4.denselayer15.norm2.weight True
# module.features.denseblock4.denselayer15.norm2.bias True
# module.features.denseblock4.denselayer15.conv2.weight True
# module.features.denseblock4.denselayer16.norm1.weight True
# module.features.denseblock4.denselayer16.norm1.bias True
# module.features.denseblock4.denselayer16.conv1.weight True
# module.features.denseblock4.denselayer16.norm2.weight True
# module.features.denseblock4.denselayer16.norm2.bias True
# module.features.denseblock4.denselayer16.conv2.weight True
# module.features.denseblock4.denselayer17.norm1.weight True
# module.features.denseblock4.denselayer17.norm1.bias True
# module.features.denseblock4.denselayer17.conv1.weight True
# module.features.denseblock4.denselayer17.norm2.weight True
# module.features.denseblock4.denselayer17.norm2.bias True
# module.features.denseblock4.denselayer17.conv2.weight True
# module.features.denseblock4.denselayer18.norm1.weight True
# module.features.denseblock4.denselayer18.norm1.bias True
# module.features.denseblock4.denselayer18.conv1.weight True
# module.features.denseblock4.denselayer18.norm2.weight True
# module.features.denseblock4.denselayer18.norm2.bias True
# module.features.denseblock4.denselayer18.conv2.weight True
# module.features.denseblock4.denselayer19.norm1.weight True
# module.features.denseblock4.denselayer19.norm1.bias True
# module.features.denseblock4.denselayer19.conv1.weight True
# module.features.denseblock4.denselayer19.norm2.weight True
# module.features.denseblock4.denselayer19.norm2.bias True
# module.features.denseblock4.denselayer19.conv2.weight True
# module.features.denseblock4.denselayer20.norm1.weight True
# module.features.denseblock4.denselayer20.norm1.bias True
# module.features.denseblock4.denselayer20.conv1.weight True
# module.features.denseblock4.denselayer20.norm2.weight True
# module.features.denseblock4.denselayer20.norm2.bias True
# module.features.denseblock4.denselayer20.conv2.weight True
# module.features.denseblock4.denselayer21.norm1.weight True
# module.features.denseblock4.denselayer21.norm1.bias True
# module.features.denseblock4.denselayer21.conv1.weight True
# module.features.denseblock4.denselayer21.norm2.weight True
# module.features.denseblock4.denselayer21.norm2.bias True
# module.features.denseblock4.denselayer21.conv2.weight True
# module.features.denseblock4.denselayer22.norm1.weight True
# module.features.denseblock4.denselayer22.norm1.bias True
# module.features.denseblock4.denselayer22.conv1.weight True
# module.features.denseblock4.denselayer22.norm2.weight True
# module.features.denseblock4.denselayer22.norm2.bias True
# module.features.denseblock4.denselayer22.conv2.weight True
# module.features.denseblock4.denselayer23.norm1.weight True
# module.features.denseblock4.denselayer23.norm1.bias True
# module.features.denseblock4.denselayer23.conv1.weight True
# module.features.denseblock4.denselayer23.norm2.weight True
# module.features.denseblock4.denselayer23.norm2.bias True
# module.features.denseblock4.denselayer23.conv2.weight True
# module.features.denseblock4.denselayer24.norm1.weight True
# module.features.denseblock4.denselayer24.norm1.bias True
# module.features.denseblock4.denselayer24.conv1.weight True
# module.features.denseblock4.denselayer24.norm2.weight True
# module.features.denseblock4.denselayer24.norm2.bias True
# module.features.denseblock4.denselayer24.conv2.weight True
# module.features.denseblock4.denselayer25.norm1.weight True
# module.features.denseblock4.denselayer25.norm1.bias True
# module.features.denseblock4.denselayer25.conv1.weight True
# module.features.denseblock4.denselayer25.norm2.weight True
# module.features.denseblock4.denselayer25.norm2.bias True
# module.features.denseblock4.denselayer25.conv2.weight True
# module.features.denseblock4.denselayer26.norm1.weight True
# module.features.denseblock4.denselayer26.norm1.bias True
# module.features.denseblock4.denselayer26.conv1.weight True
# module.features.denseblock4.denselayer26.norm2.weight True
# module.features.denseblock4.denselayer26.norm2.bias True
# module.features.denseblock4.denselayer26.conv2.weight True
# module.features.denseblock4.denselayer27.norm1.weight True
# module.features.denseblock4.denselayer27.norm1.bias True
# module.features.denseblock4.denselayer27.conv1.weight True
# module.features.denseblock4.denselayer27.norm2.weight True
# module.features.denseblock4.denselayer27.norm2.bias True
# module.features.denseblock4.denselayer27.conv2.weight True
# module.features.denseblock4.denselayer28.norm1.weight True
# module.features.denseblock4.denselayer28.norm1.bias True
# module.features.denseblock4.denselayer28.conv1.weight True
# module.features.denseblock4.denselayer28.norm2.weight True
# module.features.denseblock4.denselayer28.norm2.bias True
# module.features.denseblock4.denselayer28.conv2.weight True
# module.features.denseblock4.denselayer29.norm1.weight True
# module.features.denseblock4.denselayer29.norm1.bias True
# module.features.denseblock4.denselayer29.conv1.weight True
# module.features.denseblock4.denselayer29.norm2.weight True
# module.features.denseblock4.denselayer29.norm2.bias True
# module.features.denseblock4.denselayer29.conv2.weight True
# module.features.denseblock4.denselayer30.norm1.weight True
# module.features.denseblock4.denselayer30.norm1.bias True
# module.features.denseblock4.denselayer30.conv1.weight True
# module.features.denseblock4.denselayer30.norm2.weight True
# module.features.denseblock4.denselayer30.norm2.bias True
# module.features.denseblock4.denselayer30.conv2.weight True
# module.features.denseblock4.denselayer31.norm1.weight True
# module.features.denseblock4.denselayer31.norm1.bias True
# module.features.denseblock4.denselayer31.conv1.weight True
# module.features.denseblock4.denselayer31.norm2.weight True
# module.features.denseblock4.denselayer31.norm2.bias True
# module.features.denseblock4.denselayer31.conv2.weight True
# module.features.denseblock4.denselayer32.norm1.weight True
# module.features.denseblock4.denselayer32.norm1.bias True
# module.features.denseblock4.denselayer32.conv1.weight True
# module.features.denseblock4.denselayer32.norm2.weight True
# module.features.denseblock4.denselayer32.norm2.bias True
# module.features.denseblock4.denselayer32.conv2.weight True
# module.features.norm5.weight True
# module.features.norm5.bias True
# module.classifier.2.weight True
# module.classifier.2.bias True
