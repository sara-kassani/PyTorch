# %%
import os
import torchvision
from torchvision import transforms
import torch
import torch.nn as nn
import torch.optim as optim
import time
import os.path
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import copy

# %%
print("Torch Version",torch.__version__)
# Out:
# Torch Version 0.4.1

# %%
main_dir = "data/augmented"
data_dir = os.path.join(main_dir, "Wheat")
train_dir = os.path.join(data_dir, "train")
valid_dir = os.path.join(data_dir, "valid")
test_dir = os.path.join(data_dir, "test")

# %%
for root,dirs,files in os.walk(train_dir):
    print (root, len(files))

print("*"*30)
for root,dirs,files in os.walk(valid_dir):
    print (root, len(files))
    
print("*"*30)
for root,dirs,files in os.walk(test_dir):
    print (root, len(files))
# Out:
# data/augmented\Wheat\train 0
# data/augmented\Wheat\train\loged 3360
# data/augmented\Wheat\train\Nonloged 6240
# ******************************
# data/augmented\Wheat\valid 0
# data/augmented\Wheat\valid\loged 848
# data/augmented\Wheat\valid\Nonloged 1552
# ******************************
# data/augmented\Wheat\test 0
# data/augmented\Wheat\test\loged 64
# data/augmented\Wheat\test\Nonloged 122

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

# %%
dataset_mean = [0.485, 0.456, 0.406]
dataset_std = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([transforms.RandomResizedCrop(224),
#                                       transforms.RandomHorizontalFlip(),
#                                       transforms.RandomRotation(10, expand=True),
#                                       transforms.CenterCrop(224),
                                      transforms.Grayscale(num_output_channels=3),
                                      transforms.ToTensor(),
                                      transforms.Normalize(mean=dataset_mean,
                                                            std=dataset_std)])

test_transform = transforms.Compose([transforms.RandomResizedCrop(224),
                                     transforms.Grayscale(num_output_channels=3),
                                     transforms.ToTensor(),
                                     transforms.Normalize(mean=dataset_mean,
                                                            std=dataset_std)])

train_dataset =  torchvision.datasets.ImageFolder(train_dir,
                                                transform=train_transform)

valid_dataset =  torchvision.datasets.ImageFolder(train_dir,
                                                transform=train_transform)

test_dataset =  torchvision.datasets.ImageFolder(test_dir,
                                                transform=test_transform)

batch_size = 32
dataloaders = {}

dataloaders["train"] = torch.utils.data.DataLoader(train_dataset,
                                                   shuffle=True,
                                                   batch_size=batch_size,
                                                   num_workers=1)

dataloaders["valid"] = torch.utils.data.DataLoader(valid_dataset,
                                                   shuffle=True,
                                                   batch_size=batch_size,
                                                   num_workers=1)

dataloaders["test"] = torch.utils.data.DataLoader(test_dataset,
                                                  shuffle=True,
                                                  batch_size=batch_size,
                                                  num_workers=1)

dataset_sizes = {"train": len(train_dataset), 
                 "valid":len(valid_dataset),
                 "test":len(test_dataset)}

# %%
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[str(x.item()) for x in classes])

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
print(dataset_sizes)
print(device)
# Out:
# {'valid': 9600, 'test': 186, 'train': 9600}
# cuda:0

# %%
model = torchvision.models.densenet121(pretrained=True)
for param in model.parameters():
    param.requires_grad = False
    
num_features = model.classifier.in_features
#replace the classifier of the trained network with our classifier
model.classifier = nn.Linear(num_features, 2) 

criterion = nn.CrossEntropyLoss()
#replace the classifier of the trained network with our classifier
#parameters of newly constructed modules have required_grad=True by default
#model.fc = nn.Linear(num_features, num_classes) 

for param in model.classifier.parameters():
    param.requires_grad = True

model = model.to(device)
criterion = nn.CrossEntropyLoss()
#Optimize only the classifier
optimizer = torch.optim.SGD(list(filter(lambda p: p.requires_grad, model.parameters())), lr=0.001, momentum=0.9)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 20)
#         print(".", end="", sep="")
        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
#                 scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
#                 print(".", end="")
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
if torch.cuda.is_available():
    print("Cuda is available.")
    model = torch.nn.DataParallel(model).cuda();

model = train_model(model, criterion, optimizer, scheduler=None, num_epochs=50)
# Out:
# Cuda is available.
# Epoch 0/49
# --------------------
# train Loss: 0.4200 Acc: 0.8036
# valid Loss: 0.3761 Acc: 0.8376
#
# Epoch 1/49
# --------------------
# train Loss: 0.3777 Acc: 0.8348
# valid Loss: 0.3592 Acc: 0.8419
#
# Epoch 2/49
# --------------------
# train Loss: 0.3840 Acc: 0.8292
# valid Loss: 0.3569 Acc: 0.8466
#
# Epoch 3/49
# --------------------
# train Loss: 0.3781 Acc: 0.8317
# valid Loss: 0.3562 Acc: 0.8435
#
# Epoch 4/49
# --------------------
# train Loss: 0.3752 Acc: 0.8372
# valid Loss: 0.3536 Acc: 0.8471
#
# Epoch 5/49
# --------------------
# train Loss: 0.3823 Acc: 0.8301
# valid Loss: 0.3514 Acc: 0.8457
#
# Epoch 6/49
# --------------------
# train Loss: 0.3703 Acc: 0.8373
# valid Loss: 0.3438 Acc: 0.8496
#
# Epoch 7/49
# --------------------
# train Loss: 0.3703 Acc: 0.8354
# valid Loss: 0.3432 Acc: 0.8513
#
# Epoch 8/49
# --------------------
# train Loss: 0.3704 Acc: 0.8376
# valid Loss: 0.3434 Acc: 0.8539
#
# Epoch 9/49
# --------------------
# train Loss: 0.3609 Acc: 0.8368
# valid Loss: 0.3502 Acc: 0.8503
#
# Epoch 10/49
# --------------------
# train Loss: 0.3762 Acc: 0.8340
# valid Loss: 0.3521 Acc: 0.8563
#
# Epoch 11/49
# --------------------
# train Loss: 0.3616 Acc: 0.8448
# valid Loss: 0.3589 Acc: 0.8493
#
# Epoch 12/49
# --------------------
# train Loss: 0.3735 Acc: 0.8348
# valid Loss: 0.3371 Acc: 0.8557
#
# Epoch 13/49
# --------------------
# train Loss: 0.3688 Acc: 0.8360
# valid Loss: 0.3464 Acc: 0.8532
#
# Epoch 14/49
# --------------------
# train Loss: 0.3767 Acc: 0.8328
# valid Loss: 0.3559 Acc: 0.8374
#
# Epoch 15/49
# --------------------
# train Loss: 0.3599 Acc: 0.8453
# valid Loss: 0.3404 Acc: 0.8465
#
# Epoch 16/49
# --------------------
# train Loss: 0.3675 Acc: 0.8338
# valid Loss: 0.3526 Acc: 0.8402
#
# Epoch 17/49
# --------------------
# train Loss: 0.3683 Acc: 0.8388
# valid Loss: 0.3500 Acc: 0.8450
#
# Epoch 18/49
# --------------------
# train Loss: 0.3809 Acc: 0.8329
# valid Loss: 0.3458 Acc: 0.8491
#
# Epoch 19/49
# --------------------
# train Loss: 0.3631 Acc: 0.8431
# valid Loss: 0.3497 Acc: 0.8407
#
# Epoch 20/49
# --------------------
# train Loss: 0.3663 Acc: 0.8407
# valid Loss: 0.3410 Acc: 0.8549
#
# Epoch 21/49
# --------------------
# train Loss: 0.3614 Acc: 0.8407
# valid Loss: 0.3411 Acc: 0.8524
#
# Epoch 22/49
# --------------------
# train Loss: 0.3660 Acc: 0.8383
# valid Loss: 0.3426 Acc: 0.8506
#
# Epoch 23/49
# --------------------
# train Loss: 0.3593 Acc: 0.8417
# valid Loss: 0.3568 Acc: 0.8399
#
# Epoch 24/49
# --------------------
# train Loss: 0.3564 Acc: 0.8429
# valid Loss: 0.3408 Acc: 0.8491
#
# Epoch 25/49
# --------------------
# train Loss: 0.3713 Acc: 0.8353
# valid Loss: 0.3501 Acc: 0.8424
#
# Epoch 26/49
# --------------------
# train Loss: 0.3690 Acc: 0.8384
# valid Loss: 0.3786 Acc: 0.8270
#
# Epoch 27/49
# --------------------
# train Loss: 0.3670 Acc: 0.8407
# valid Loss: 0.3570 Acc: 0.8424
#
# Epoch 28/49
# --------------------
# train Loss: 0.3820 Acc: 0.8308
# valid Loss: 0.3494 Acc: 0.8535
#
# Epoch 29/49
# --------------------
# train Loss: 0.3676 Acc: 0.8364
# valid Loss: 0.3824 Acc: 0.8401
#
# Epoch 30/49
# --------------------
# train Loss: 0.3676 Acc: 0.8369
# valid Loss: 0.3492 Acc: 0.8472
#
# Epoch 31/49
# --------------------
# train Loss: 0.3622 Acc: 0.8410
# valid Loss: 0.3366 Acc: 0.8541
#
# Epoch 32/49
# --------------------
# train Loss: 0.3799 Acc: 0.8336
# valid Loss: 0.3421 Acc: 0.8532
#
# Epoch 33/49
# --------------------
# train Loss: 0.3617 Acc: 0.8446
# valid Loss: 0.3372 Acc: 0.8495
#
# Epoch 34/49
# --------------------
# train Loss: 0.3764 Acc: 0.8343
# valid Loss: 0.3411 Acc: 0.8563
#
# Epoch 35/49
# --------------------
# train Loss: 0.3648 Acc: 0.8416
# valid Loss: 0.3654 Acc: 0.8431
#
# Epoch 36/49
# --------------------
# train Loss: 0.3623 Acc: 0.8381
# valid Loss: 0.3405 Acc: 0.8514
#
# Epoch 37/49
# --------------------
# train Loss: 0.3704 Acc: 0.8359
# valid Loss: 0.3392 Acc: 0.8541
#
# Epoch 38/49
# --------------------
# train Loss: 0.3586 Acc: 0.8449
# valid Loss: 0.3459 Acc: 0.8544
#
# Epoch 39/49
# --------------------
# train Loss: 0.3720 Acc: 0.8348
# valid Loss: 0.4472 Acc: 0.8130
#
# Epoch 40/49
# --------------------
# train Loss: 0.3712 Acc: 0.8375
# valid Loss: 0.3452 Acc: 0.8433
#
# Epoch 41/49
# --------------------
# train Loss: 0.3740 Acc: 0.8366
# valid Loss: 0.3333 Acc: 0.8560
#
# Epoch 42/49
# --------------------
# train Loss: 0.3617 Acc: 0.8432
# valid Loss: 0.3345 Acc: 0.8567
#
# Epoch 43/49
# --------------------
# train Loss: 0.3578 Acc: 0.8420
# valid Loss: 0.3557 Acc: 0.8505
#
# Epoch 44/49
# --------------------
# train Loss: 0.3718 Acc: 0.8359
# valid Loss: 0.3502 Acc: 0.8418
#
# Epoch 45/49
# --------------------
# train Loss: 0.3696 Acc: 0.8358
# valid Loss: 0.3403 Acc: 0.8528
#
# Epoch 46/49
# --------------------
# train Loss: 0.3556 Acc: 0.8411
# valid Loss: 0.3519 Acc: 0.8441
#
# Epoch 47/49
# --------------------
# train Loss: 0.3655 Acc: 0.8424
# valid Loss: 0.3369 Acc: 0.8559
#
# Epoch 48/49
# --------------------
# train Loss: 0.3629 Acc: 0.8408
# valid Loss: 0.3445 Acc: 0.8527
#
# Epoch 49/49
# --------------------
# train Loss: 0.3549 Acc: 0.8403
# valid Loss: 0.3480 Acc: 0.8433
#
# Training complete in 110m 30s
# Best val Acc: 0.856667

# %%
torch.save(model.state_dict(), "models/07.Wheat-DenseNet121_augmented.pth")

# %%
correct = 0
total = 0
loss = 0
y_pred = []
y_true = []

with torch.no_grad():
    for data in dataloaders["test"]:
        images, labels = data
        images = images.cuda()
        labels = labels.cuda()
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        test_loss = criterion(outputs, labels)
        
        y_pred += predicted.to("cpu").detach().numpy().tolist()
        y_true += labels.to("cpu").detach().numpy().tolist()
        
print('Test accuracy: {:.4f}' .format( 100 * correct / total))
print('Test Loss: %.4f'%(test_loss))
# Out:
# Test accuracy: 88.7097
# Test Loss: 0.1568

# %%
plt.rcParams["axes.grid"] = False
plt.rcParams.update({'font.size': 20})

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred)

   
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion Matrix')

    print(cm)
#     fig = plt.figure()
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
#     plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
#     plt.savefig('plots/3.InceptionV3-2-Private-DataSet-CM.png', bbox_inches='tight', dpi = 100) 
plt.figure(figsize=(10,10))

labels = ['0', '1']

plot_confusion_matrix(cm, classes=labels,
                      title='Confusion Matrix')
# Out:
# Confusion Matrix
# [[111  11]
#  [ 10  54]]

# %%
cm = confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# [[111  11]
#  [ 10  54]]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
classnames=[]
for classname in dataloaders["test"]:
    classnames.append(classname)

confusion_mtx = confusion_matrix(y_true, y_pred) 
print(confusion_mtx)
target_names = classnames
# print(classification_report(y_true, y_pred, target_names=target_names))
print(classification_report(y_true, y_pred))
# Out:
# [[111  11]
#  [ 10  54]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91       122
#            1       0.83      0.84      0.84        64
#
#    micro avg       0.89      0.89      0.89       186
#    macro avg       0.87      0.88      0.88       186
# weighted avg       0.89      0.89      0.89       186

# %%
total=sum(sum(cm))

accuracy = (cm[0,0]+cm[1,1]) / total
print ('Accuracy : ', accuracy*100)

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity*100 )

Specificity = cm[1,1]/(cm[1,1]+cm[0,1])
print('Specificity : ', Specificity*100 )
# Out:
# Accuracy :  88.70967741935483
# Sensitivity :  91.73553719008265
# Specificity :  83.07692307692308

# %%
plt.rcParams["axes.grid"] = False
plt.rcParams.update({'font.size': 14})

from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_true, y_pred)
roc_auc = auc(fpr, tpr)

import matplotlib.pyplot as plt

plt.figure()
lw = 1
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

#plotting sensitivity and specificity
plt.figure()
plt.plot(thresholds, 1-fpr, label = 'specificity')
plt.plot(thresholds, tpr, label = 'sensitivity')
plt.legend()
plt.grid()
plt.xlabel('Threshold value')
plt.show()

# %%
# To view which layers are freeze and which layers are not freezed:
for name, child in model.named_children():
    for name_2, params in child.named_parameters():
        print(name_2, params.requires_grad)
# Out:
# features.conv0.weight False
# features.norm0.weight False
# features.norm0.bias False
# features.denseblock1.denselayer1.norm1.weight False
# features.denseblock1.denselayer1.norm1.bias False
# features.denseblock1.denselayer1.conv1.weight False
# features.denseblock1.denselayer1.norm2.weight False
# features.denseblock1.denselayer1.norm2.bias False
# features.denseblock1.denselayer1.conv2.weight False
# features.denseblock1.denselayer2.norm1.weight False
# features.denseblock1.denselayer2.norm1.bias False
# features.denseblock1.denselayer2.conv1.weight False
# features.denseblock1.denselayer2.norm2.weight False
# features.denseblock1.denselayer2.norm2.bias False
# features.denseblock1.denselayer2.conv2.weight False
# features.denseblock1.denselayer3.norm1.weight False
# features.denseblock1.denselayer3.norm1.bias False
# features.denseblock1.denselayer3.conv1.weight False
# features.denseblock1.denselayer3.norm2.weight False
# features.denseblock1.denselayer3.norm2.bias False
# features.denseblock1.denselayer3.conv2.weight False
# features.denseblock1.denselayer4.norm1.weight False
# features.denseblock1.denselayer4.norm1.bias False
# features.denseblock1.denselayer4.conv1.weight False
# features.denseblock1.denselayer4.norm2.weight False
# features.denseblock1.denselayer4.norm2.bias False
# features.denseblock1.denselayer4.conv2.weight False
# features.denseblock1.denselayer5.norm1.weight False
# features.denseblock1.denselayer5.norm1.bias False
# features.denseblock1.denselayer5.conv1.weight False
# features.denseblock1.denselayer5.norm2.weight False
# features.denseblock1.denselayer5.norm2.bias False
# features.denseblock1.denselayer5.conv2.weight False
# features.denseblock1.denselayer6.norm1.weight False
# features.denseblock1.denselayer6.norm1.bias False
# features.denseblock1.denselayer6.conv1.weight False
# features.denseblock1.denselayer6.norm2.weight False
# features.denseblock1.denselayer6.norm2.bias False
# features.denseblock1.denselayer6.conv2.weight False
# features.transition1.norm.weight False
# features.transition1.norm.bias False
# features.transition1.conv.weight False
# features.denseblock2.denselayer1.norm1.weight False
# features.denseblock2.denselayer1.norm1.bias False
# features.denseblock2.denselayer1.conv1.weight False
# features.denseblock2.denselayer1.norm2.weight False
# features.denseblock2.denselayer1.norm2.bias False
# features.denseblock2.denselayer1.conv2.weight False
# features.denseblock2.denselayer2.norm1.weight False
# features.denseblock2.denselayer2.norm1.bias False
# features.denseblock2.denselayer2.conv1.weight False
# features.denseblock2.denselayer2.norm2.weight False
# features.denseblock2.denselayer2.norm2.bias False
# features.denseblock2.denselayer2.conv2.weight False
# features.denseblock2.denselayer3.norm1.weight False
# features.denseblock2.denselayer3.norm1.bias False
# features.denseblock2.denselayer3.conv1.weight False
# features.denseblock2.denselayer3.norm2.weight False
# features.denseblock2.denselayer3.norm2.bias False
# features.denseblock2.denselayer3.conv2.weight False
# features.denseblock2.denselayer4.norm1.weight False
# features.denseblock2.denselayer4.norm1.bias False
# features.denseblock2.denselayer4.conv1.weight False
# features.denseblock2.denselayer4.norm2.weight False
# features.denseblock2.denselayer4.norm2.bias False
# features.denseblock2.denselayer4.conv2.weight False
# features.denseblock2.denselayer5.norm1.weight False
# features.denseblock2.denselayer5.norm1.bias False
# features.denseblock2.denselayer5.conv1.weight False
# features.denseblock2.denselayer5.norm2.weight False
# features.denseblock2.denselayer5.norm2.bias False
# features.denseblock2.denselayer5.conv2.weight False
# features.denseblock2.denselayer6.norm1.weight False
# features.denseblock2.denselayer6.norm1.bias False
# features.denseblock2.denselayer6.conv1.weight False
# features.denseblock2.denselayer6.norm2.weight False
# features.denseblock2.denselayer6.norm2.bias False
# features.denseblock2.denselayer6.conv2.weight False
# features.denseblock2.denselayer7.norm1.weight False
# features.denseblock2.denselayer7.norm1.bias False
# features.denseblock2.denselayer7.conv1.weight False
# features.denseblock2.denselayer7.norm2.weight False
# features.denseblock2.denselayer7.norm2.bias False
# features.denseblock2.denselayer7.conv2.weight False
# features.denseblock2.denselayer8.norm1.weight False
# features.denseblock2.denselayer8.norm1.bias False
# features.denseblock2.denselayer8.conv1.weight False
# features.denseblock2.denselayer8.norm2.weight False
# features.denseblock2.denselayer8.norm2.bias False
# features.denseblock2.denselayer8.conv2.weight False
# features.denseblock2.denselayer9.norm1.weight False
# features.denseblock2.denselayer9.norm1.bias False
# features.denseblock2.denselayer9.conv1.weight False
# features.denseblock2.denselayer9.norm2.weight False
# features.denseblock2.denselayer9.norm2.bias False
# features.denseblock2.denselayer9.conv2.weight False
# features.denseblock2.denselayer10.norm1.weight False
# features.denseblock2.denselayer10.norm1.bias False
# features.denseblock2.denselayer10.conv1.weight False
# features.denseblock2.denselayer10.norm2.weight False
# features.denseblock2.denselayer10.norm2.bias False
# features.denseblock2.denselayer10.conv2.weight False
# features.denseblock2.denselayer11.norm1.weight False
# features.denseblock2.denselayer11.norm1.bias False
# features.denseblock2.denselayer11.conv1.weight False
# features.denseblock2.denselayer11.norm2.weight False
# features.denseblock2.denselayer11.norm2.bias False
# features.denseblock2.denselayer11.conv2.weight False
# features.denseblock2.denselayer12.norm1.weight False
# features.denseblock2.denselayer12.norm1.bias False
# features.denseblock2.denselayer12.conv1.weight False
# features.denseblock2.denselayer12.norm2.weight False
# features.denseblock2.denselayer12.norm2.bias False
# features.denseblock2.denselayer12.conv2.weight False
# features.transition2.norm.weight False
# features.transition2.norm.bias False
# features.transition2.conv.weight False
# features.denseblock3.denselayer1.norm1.weight False
# features.denseblock3.denselayer1.norm1.bias False
# features.denseblock3.denselayer1.conv1.weight False
# features.denseblock3.denselayer1.norm2.weight False
# features.denseblock3.denselayer1.norm2.bias False
# features.denseblock3.denselayer1.conv2.weight False
# features.denseblock3.denselayer2.norm1.weight False
# features.denseblock3.denselayer2.norm1.bias False
# features.denseblock3.denselayer2.conv1.weight False
# features.denseblock3.denselayer2.norm2.weight False
# features.denseblock3.denselayer2.norm2.bias False
# features.denseblock3.denselayer2.conv2.weight False
# features.denseblock3.denselayer3.norm1.weight False
# features.denseblock3.denselayer3.norm1.bias False
# features.denseblock3.denselayer3.conv1.weight False
# features.denseblock3.denselayer3.norm2.weight False
# features.denseblock3.denselayer3.norm2.bias False
# features.denseblock3.denselayer3.conv2.weight False
# features.denseblock3.denselayer4.norm1.weight False
# features.denseblock3.denselayer4.norm1.bias False
# features.denseblock3.denselayer4.conv1.weight False
# features.denseblock3.denselayer4.norm2.weight False
# features.denseblock3.denselayer4.norm2.bias False
# features.denseblock3.denselayer4.conv2.weight False
# features.denseblock3.denselayer5.norm1.weight False
# features.denseblock3.denselayer5.norm1.bias False
# features.denseblock3.denselayer5.conv1.weight False
# features.denseblock3.denselayer5.norm2.weight False
# features.denseblock3.denselayer5.norm2.bias False
# features.denseblock3.denselayer5.conv2.weight False
# features.denseblock3.denselayer6.norm1.weight False
# features.denseblock3.denselayer6.norm1.bias False
# features.denseblock3.denselayer6.conv1.weight False
# features.denseblock3.denselayer6.norm2.weight False
# features.denseblock3.denselayer6.norm2.bias False
# features.denseblock3.denselayer6.conv2.weight False
# features.denseblock3.denselayer7.norm1.weight False
# features.denseblock3.denselayer7.norm1.bias False
# features.denseblock3.denselayer7.conv1.weight False
# features.denseblock3.denselayer7.norm2.weight False
# features.denseblock3.denselayer7.norm2.bias False
# features.denseblock3.denselayer7.conv2.weight False
# features.denseblock3.denselayer8.norm1.weight False
# features.denseblock3.denselayer8.norm1.bias False
# features.denseblock3.denselayer8.conv1.weight False
# features.denseblock3.denselayer8.norm2.weight False
# features.denseblock3.denselayer8.norm2.bias False
# features.denseblock3.denselayer8.conv2.weight False
# features.denseblock3.denselayer9.norm1.weight False
# features.denseblock3.denselayer9.norm1.bias False
# features.denseblock3.denselayer9.conv1.weight False
# features.denseblock3.denselayer9.norm2.weight False
# features.denseblock3.denselayer9.norm2.bias False
# features.denseblock3.denselayer9.conv2.weight False
# features.denseblock3.denselayer10.norm1.weight False
# features.denseblock3.denselayer10.norm1.bias False
# features.denseblock3.denselayer10.conv1.weight False
# features.denseblock3.denselayer10.norm2.weight False
# features.denseblock3.denselayer10.norm2.bias False
# features.denseblock3.denselayer10.conv2.weight False
# features.denseblock3.denselayer11.norm1.weight False
# features.denseblock3.denselayer11.norm1.bias False
# features.denseblock3.denselayer11.conv1.weight False
# features.denseblock3.denselayer11.norm2.weight False
# features.denseblock3.denselayer11.norm2.bias False
# features.denseblock3.denselayer11.conv2.weight False
# features.denseblock3.denselayer12.norm1.weight False
# features.denseblock3.denselayer12.norm1.bias False
# features.denseblock3.denselayer12.conv1.weight False
# features.denseblock3.denselayer12.norm2.weight False
# features.denseblock3.denselayer12.norm2.bias False
# features.denseblock3.denselayer12.conv2.weight False
# features.denseblock3.denselayer13.norm1.weight False
# features.denseblock3.denselayer13.norm1.bias False
# features.denseblock3.denselayer13.conv1.weight False
# features.denseblock3.denselayer13.norm2.weight False
# features.denseblock3.denselayer13.norm2.bias False
# features.denseblock3.denselayer13.conv2.weight False
# features.denseblock3.denselayer14.norm1.weight False
# features.denseblock3.denselayer14.norm1.bias False
# features.denseblock3.denselayer14.conv1.weight False
# features.denseblock3.denselayer14.norm2.weight False
# features.denseblock3.denselayer14.norm2.bias False
# features.denseblock3.denselayer14.conv2.weight False
# features.denseblock3.denselayer15.norm1.weight False
# features.denseblock3.denselayer15.norm1.bias False
# features.denseblock3.denselayer15.conv1.weight False
# features.denseblock3.denselayer15.norm2.weight False
# features.denseblock3.denselayer15.norm2.bias False
# features.denseblock3.denselayer15.conv2.weight False
# features.denseblock3.denselayer16.norm1.weight False
# features.denseblock3.denselayer16.norm1.bias False
# features.denseblock3.denselayer16.conv1.weight False
# features.denseblock3.denselayer16.norm2.weight False
# features.denseblock3.denselayer16.norm2.bias False
# features.denseblock3.denselayer16.conv2.weight False
# features.denseblock3.denselayer17.norm1.weight False
# features.denseblock3.denselayer17.norm1.bias False
# features.denseblock3.denselayer17.conv1.weight False
# features.denseblock3.denselayer17.norm2.weight False
# features.denseblock3.denselayer17.norm2.bias False
# features.denseblock3.denselayer17.conv2.weight False
# features.denseblock3.denselayer18.norm1.weight False
# features.denseblock3.denselayer18.norm1.bias False
# features.denseblock3.denselayer18.conv1.weight False
# features.denseblock3.denselayer18.norm2.weight False
# features.denseblock3.denselayer18.norm2.bias False
# features.denseblock3.denselayer18.conv2.weight False
# features.denseblock3.denselayer19.norm1.weight False
# features.denseblock3.denselayer19.norm1.bias False
# features.denseblock3.denselayer19.conv1.weight False
# features.denseblock3.denselayer19.norm2.weight False
# features.denseblock3.denselayer19.norm2.bias False
# features.denseblock3.denselayer19.conv2.weight False
# features.denseblock3.denselayer20.norm1.weight False
# features.denseblock3.denselayer20.norm1.bias False
# features.denseblock3.denselayer20.conv1.weight False
# features.denseblock3.denselayer20.norm2.weight False
# features.denseblock3.denselayer20.norm2.bias False
# features.denseblock3.denselayer20.conv2.weight False
# features.denseblock3.denselayer21.norm1.weight False
# features.denseblock3.denselayer21.norm1.bias False
# features.denseblock3.denselayer21.conv1.weight False
# features.denseblock3.denselayer21.norm2.weight False
# features.denseblock3.denselayer21.norm2.bias False
# features.denseblock3.denselayer21.conv2.weight False
# features.denseblock3.denselayer22.norm1.weight False
# features.denseblock3.denselayer22.norm1.bias False
# features.denseblock3.denselayer22.conv1.weight False
# features.denseblock3.denselayer22.norm2.weight False
# features.denseblock3.denselayer22.norm2.bias False
# features.denseblock3.denselayer22.conv2.weight False
# features.denseblock3.denselayer23.norm1.weight False
# features.denseblock3.denselayer23.norm1.bias False
# features.denseblock3.denselayer23.conv1.weight False
# features.denseblock3.denselayer23.norm2.weight False
# features.denseblock3.denselayer23.norm2.bias False
# features.denseblock3.denselayer23.conv2.weight False
# features.denseblock3.denselayer24.norm1.weight False
# features.denseblock3.denselayer24.norm1.bias False
# features.denseblock3.denselayer24.conv1.weight False
# features.denseblock3.denselayer24.norm2.weight False
# features.denseblock3.denselayer24.norm2.bias False
# features.denseblock3.denselayer24.conv2.weight False
# features.transition3.norm.weight False
# features.transition3.norm.bias False
# features.transition3.conv.weight False
# features.denseblock4.denselayer1.norm1.weight False
# features.denseblock4.denselayer1.norm1.bias False
# features.denseblock4.denselayer1.conv1.weight False
# features.denseblock4.denselayer1.norm2.weight False
# features.denseblock4.denselayer1.norm2.bias False
# features.denseblock4.denselayer1.conv2.weight False
# features.denseblock4.denselayer2.norm1.weight False
# features.denseblock4.denselayer2.norm1.bias False
# features.denseblock4.denselayer2.conv1.weight False
# features.denseblock4.denselayer2.norm2.weight False
# features.denseblock4.denselayer2.norm2.bias False
# features.denseblock4.denselayer2.conv2.weight False
# features.denseblock4.denselayer3.norm1.weight False
# features.denseblock4.denselayer3.norm1.bias False
# features.denseblock4.denselayer3.conv1.weight False
# features.denseblock4.denselayer3.norm2.weight False
# features.denseblock4.denselayer3.norm2.bias False
# features.denseblock4.denselayer3.conv2.weight False
# features.denseblock4.denselayer4.norm1.weight False
# features.denseblock4.denselayer4.norm1.bias False
# features.denseblock4.denselayer4.conv1.weight False
# features.denseblock4.denselayer4.norm2.weight False
# features.denseblock4.denselayer4.norm2.bias False
# features.denseblock4.denselayer4.conv2.weight False
# features.denseblock4.denselayer5.norm1.weight False
# features.denseblock4.denselayer5.norm1.bias False
# features.denseblock4.denselayer5.conv1.weight False
# features.denseblock4.denselayer5.norm2.weight False
# features.denseblock4.denselayer5.norm2.bias False
# features.denseblock4.denselayer5.conv2.weight False
# features.denseblock4.denselayer6.norm1.weight False
# features.denseblock4.denselayer6.norm1.bias False
# features.denseblock4.denselayer6.conv1.weight False
# features.denseblock4.denselayer6.norm2.weight False
# features.denseblock4.denselayer6.norm2.bias False
# features.denseblock4.denselayer6.conv2.weight False
# features.denseblock4.denselayer7.norm1.weight False
# features.denseblock4.denselayer7.norm1.bias False
# features.denseblock4.denselayer7.conv1.weight False
# features.denseblock4.denselayer7.norm2.weight False
# features.denseblock4.denselayer7.norm2.bias False
# features.denseblock4.denselayer7.conv2.weight False
# features.denseblock4.denselayer8.norm1.weight False
# features.denseblock4.denselayer8.norm1.bias False
# features.denseblock4.denselayer8.conv1.weight False
# features.denseblock4.denselayer8.norm2.weight False
# features.denseblock4.denselayer8.norm2.bias False
# features.denseblock4.denselayer8.conv2.weight False
# features.denseblock4.denselayer9.norm1.weight False
# features.denseblock4.denselayer9.norm1.bias False
# features.denseblock4.denselayer9.conv1.weight False
# features.denseblock4.denselayer9.norm2.weight False
# features.denseblock4.denselayer9.norm2.bias False
# features.denseblock4.denselayer9.conv2.weight False
# features.denseblock4.denselayer10.norm1.weight False
# features.denseblock4.denselayer10.norm1.bias False
# features.denseblock4.denselayer10.conv1.weight False
# features.denseblock4.denselayer10.norm2.weight False
# features.denseblock4.denselayer10.norm2.bias False
# features.denseblock4.denselayer10.conv2.weight False
# features.denseblock4.denselayer11.norm1.weight False
# features.denseblock4.denselayer11.norm1.bias False
# features.denseblock4.denselayer11.conv1.weight False
# features.denseblock4.denselayer11.norm2.weight False
# features.denseblock4.denselayer11.norm2.bias False
# features.denseblock4.denselayer11.conv2.weight False
# features.denseblock4.denselayer12.norm1.weight False
# features.denseblock4.denselayer12.norm1.bias False
# features.denseblock4.denselayer12.conv1.weight False
# features.denseblock4.denselayer12.norm2.weight False
# features.denseblock4.denselayer12.norm2.bias False
# features.denseblock4.denselayer12.conv2.weight False
# features.denseblock4.denselayer13.norm1.weight False
# features.denseblock4.denselayer13.norm1.bias False
# features.denseblock4.denselayer13.conv1.weight False
# features.denseblock4.denselayer13.norm2.weight False
# features.denseblock4.denselayer13.norm2.bias False
# features.denseblock4.denselayer13.conv2.weight False
# features.denseblock4.denselayer14.norm1.weight False
# features.denseblock4.denselayer14.norm1.bias False
# features.denseblock4.denselayer14.conv1.weight False
# features.denseblock4.denselayer14.norm2.weight False
# features.denseblock4.denselayer14.norm2.bias False
# features.denseblock4.denselayer14.conv2.weight False
# features.denseblock4.denselayer15.norm1.weight False
# features.denseblock4.denselayer15.norm1.bias False
# features.denseblock4.denselayer15.conv1.weight False
# features.denseblock4.denselayer15.norm2.weight False
# features.denseblock4.denselayer15.norm2.bias False
# features.denseblock4.denselayer15.conv2.weight False
# features.denseblock4.denselayer16.norm1.weight False
# features.denseblock4.denselayer16.norm1.bias False
# features.denseblock4.denselayer16.conv1.weight False
# features.denseblock4.denselayer16.norm2.weight False
# features.denseblock4.denselayer16.norm2.bias False
# features.denseblock4.denselayer16.conv2.weight False
# features.norm5.weight False
# features.norm5.bias False
# classifier.weight True
# classifier.bias True
